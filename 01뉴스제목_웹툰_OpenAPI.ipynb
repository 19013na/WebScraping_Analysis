# %% [markdown]
# ## 1. 뉴스제목 가져오기
# * user-agent 요청헤더를 반드시 설정해야 한다.

# %%
# requests 라이브러리 설치여부 확인
# %pip show requests
# Out:
# Name: requests
# Version: 2.32.3
# Summary: Python HTTP for Humans.
# Home-page: https://requests.readthedocs.io
# Author: Kenneth Reitz
# Author-email: me@kennethreitz.org
# License: Apache-2.0
# Location: c:\Users\yondu\anaconda3\Lib\site-packages
# Requires: certifi, charset-normalizer, idna, urllib3
# Required-by: aext-assistant-server, anaconda-catalogs, anaconda-client, anaconda-cloud-auth, anaconda-project, conda, conda-build, conda-repo-cli, conda_package_streaming, cookiecutter, datashader, jupyterlab_server, panel, requests-file, requests-toolbelt, Sphinx, streamlit, tldextract
# Note: you may need to restart the kernel to use updated packages.

# %%
# beautifulsoup4 라이브러리 설치여부 확인
# !pip show beautifulsoup4
# Out:
# Name: beautifulsoup4
# Version: 4.12.3
# Summary: Screen-scraping library
# Home-page: https://www.crummy.com/software/BeautifulSoup/bs4/
# Author:
# Author-email: Leonard Richardson <leonardr@segfault.org>
# License: MIT License
# Location: C:\Users\yondu\anaconda3\Lib\site-packages
# Requires: soupsieve
# Required-by: conda-build, nbconvert

# %%
# reqeusts, bs4 import
import requests
import bs4
# BeautifulSoup 클래스 import
from bs4 import BeautifulSoup

# %%
# requests, bs4 버전 확인하기
print(f'requests 버전 : {requests.__version__}')
print(f'beautifulsoup4 버전 : {bs4.__version__}')
# Out:
# requests 버전 : 2.32.3
# beautifulsoup4 버전 : 4.12.3

# %% [markdown]
# ### 1. 뉴스 제목 추출하기

# %%
# IT/과학 뉴스 
req_param = {
    'sid': 105
}

url = 'https://news.naver.com/section/{sid}'.format(**req_param)
print(url)

#url2 = 'https://news.naver.com/section/105'

# 요청 헤더 설정 : 브라우저 정보
req_header = {
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/135.0.0.0 Safari/537.36'   
}

# requests 의 get() 함수 호출하기 
res = requests.get(url, headers=req_header)

#print(res)  #<Response [200]>
#print(type(res)) # <class 'requests.models.Response'>
#print(res.status_code) # 200
#print(res.status_code, res.ok) # 200 true

# 응답(response)이 OK 이면
if res.ok:
    # 응답 (response)에서 text 추출
    html = res.text
    #print(html) # 해당 page(url)의 모든 text를 가져옴

    # BeautifulSoup 객체 생성  
    soup = BeautifulSoup(html, 'html.parser')
    #print(soup)
    
    # CSS 선택자
    # <div class='sa_text'><a></a></div>
    print(len(soup.select("div.sa_text a[href*='mnews/article']")))
    
    a_tag_list = soup.select("div.sa_text a[href*='mnews/article']")
    #print(type(a_tag_list)) # [<a href="http://">뉴스제목</a>] ResultSet객체 , <a>text</a> : Tag 객체
    #print(a_tag_list)

    # <a> 태그 리스트 순회하기
    for a_tag in a_tag_list:
        #print(type(a_tag))
        title = a_tag.text.strip()
        
        # href 속성의 값을 가져오기
        link = a_tag['href']
        print(link, title)
        
else:
    # 응답(response)이 Error 이면 status code 출력    
    print(f'Error code : {res.status_code}')
# Out:
# https://news.naver.com/section/105
# 86
# https://n.news.naver.com/mnews/article/052/0002177123 우주청, 우즈베키스탄·이탈리아와 손잡고 우주 국제협력 본격화
# https://n.news.naver.com/mnews/article/comment/052/0002177123
# https://n.news.naver.com/mnews/article/025/0003432668 기업은행 SKT와 손잡고, 보이스피싱 AI로 실시간 탐지한다
# https://n.news.naver.com/mnews/article/comment/025/0003432668
# https://n.news.naver.com/mnews/article/421/0008180201 "생활형 AI 시대 연다"…뤼튼테크놀로지스 '뤼튼 3.0' 발표
# https://n.news.naver.com/mnews/article/comment/421/0008180201
# https://n.news.naver.com/mnews/article/021/0002701759 스미싱 등 악성 문자, 발송단계부터 차단한다
# https://n.news.naver.com/mnews/article/comment/021/0002701759
# https://n.news.naver.com/mnews/article/009/0005472817 “1초만에 99.5% 정확도로 상품 인식”…신세계아이앤씨, AI 리테일테크 시장 정조준
# https://n.news.naver.com/mnews/article/comment/009/0005472817
# https://n.news.naver.com/mnews/article/018/0005982223 카카오의 소상공인 판로 제공 실험 결실…착한 소비 1조원 돌파
# https://n.news.naver.com/mnews/article/comment/018/0005982223
# ...

# %% [markdown]
# ### 1.1 뉴스제목 추출하는 함수 선언하기

# %%
import requests
from bs4 import BeautifulSoup

section_dict = {100:'정치',101:'경제',102:'사회',103:'생활/문화',104:'세계',105:'IT/과학'}

def print_news(sid):  #print_new(103,'생활/문화') 
    
    section = section_dict[sid]
    url = f'https://news.naver.com/section/{sid}'

    # 요청 헤더 설정 : 브라우저 정보
    req_header = {
        'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/135.0.0.0 Safari/537.36'   
    }

    # requests 의 get() 함수 호출하기 
    res = requests.get(url, headers=req_header)

    # 응답(response)이 OK 이면
    if res.ok:
        # 응답 (response)에서 text 추출
        html = res.text
        
        # BeautifulSoup 객체 생성  
        soup = BeautifulSoup(html, 'html.parser')
        
        # CSS 선택자
        a_tag_list = soup.select("div.sa_text a[href*='mnews/article']")

        print(f'=====> {url} {section}뉴스 <=====')
        print(f'{len(a_tag_list)}\n')
        
        # <a> 태그 리스트 순회하기
        for a_tag in a_tag_list:
            #print(type(a_tag))
            title = a_tag.text.strip()
            
            # href 속성의 값을 가져오기
            link = a_tag['href']
            print(f'{title} \n기사링크 = {link}')
            
    else:
        # 응답(response)이 Error 이면 status code 출력    
        print(f'Error code : {res.status_code}')

# %%
print_news(103)
# Out:
# =====> https://news.naver.com/section/103 생활/문화뉴스 <=====
# 86
#
# 32년 만에 무대로 돌아온 이영애 “연극에서의 이영애는 분명 다를 것”
# 기사링크 = https://n.news.naver.com/mnews/article/032/0003362012
#
# 기사링크 = https://n.news.naver.com/mnews/article/comment/032/0003362012
# KGM 상품성 강화한 ‘토레스 EVX ALPHA’ 출시
# 기사링크 = https://n.news.naver.com/mnews/article/022/0004025942
#
# 기사링크 = https://n.news.naver.com/mnews/article/comment/022/0004025942
# 세계평화통일가정연합 "경기 가평에 천원궁 박물관 개관"
# 기사링크 = https://n.news.naver.com/mnews/article/025/0003432685
#
# 기사링크 = https://n.news.naver.com/mnews/article/comment/025/0003432685
# 국립민속박물관 2031년 세종 이전…“한국 넘어 세계 민속 콘텐츠 제공”(종합)
# 기사링크 = https://n.news.naver.com/mnews/article/277/0005574695
#
# 기사링크 = https://n.news.naver.com/mnews/article/comment/277/0005574695
# 음저협회장 보수 79% 증액…시정명령 무시하고 방만 경영
# 기사링크 = https://n.news.naver.com/mnews/article/018/0005982373
#
# 기사링크 = https://n.news.naver.com/mnews/article/comment/018/0005982373
# 3월 韓 수입차 시장서 최다 판매된 유럽 전기차…‘볼보 EX30’
# ...

# %% [markdown]
# ### 2. Image 다운로드
# * referer 요청 헤더를 반드시 설정해야 한다.

# %%
import requests
import os


# jpg(img_urls의 jpg사진) 경로 근원지 (referer)
req_header = {
    'referer': 'https://comic.naver.com/webtoon/detail?titleId=798173&no=5&amp;weekday=thu'  
}

img_urls = [
    'https://image-comic.pstatic.net/webtoon/798173/5/20220804112251_d97bd1e1b38f0cd022e4e3639d2926b3_IMAG01_1.jpg',
    'https://image-comic.pstatic.net/webtoon/798173/5/20220804112251_d97bd1e1b38f0cd022e4e3639d2926b3_IMAG01_2.jpg',
    'https://image-comic.pstatic.net/webtoon/798173/5/20220804112251_d97bd1e1b38f0cd022e4e3639d2926b3_IMAG01_3.jpg'
]

for img_url in img_urls:
    # requests 의 get(url, headers) 함수 호출하기 
    res = requests.get(img_url, headers=req_header)
    
    if res.ok:
        # binary 응답 데이터 가져오기 : content 프로퍼티를 사용
        img_data = res.content
        
        # url에서 파일명만 추출하기
        file_name = os.path.basename(img_url)
        
        # binday data를 file에 write하기 : write binary
        with open(file_name, '+wb') as file:
            print(f'Writing to {file_name} ({len(img_data):,}bytes)')
            file.write(img_data)
# Out:
# Writing to 20220804112251_d97bd1e1b38f0cd022e4e3639d2926b3_IMAG01_1.jpg (299,319bytes)
# Writing to 20220804112251_d97bd1e1b38f0cd022e4e3639d2926b3_IMAG01_2.jpg (163,333bytes)
# Writing to 20220804112251_d97bd1e1b38f0cd022e4e3639d2926b3_IMAG01_3.jpg (182,530bytes)

# %% [markdown]
# * 현재 요청된 페이지의 image 모두 다운로드 해보기

# %%
import requests
from bs4 import BeautifulSoup
import os

url = 'https://comic.naver.com/webtoon/detail?titleId=823195&no=102&week=wed'
req_header = {
    'referer': url  
}

res = requests.get(url)
if res.ok:
    # jpg 파일의 절대경로 url를 찾기
    soup = BeautifulSoup(res.text, 'html.parser')
    #print(len(soup.select("img[src*='IMAG01']")))
    
    image_tags = soup.select("img[src*='IMAG01']")
    
    # img src를 저장할 list 선언
    img_url_list = [] #img_url_list = list() 이것도 가능

    for img_tag in image_tags:
        #print(type(img_tag), img_tag.name, img_tag)
        img_src = img_tag['src']
        img_url_list.append(img_src)
    
    print(len(img_url_list)) # 데이터 확인

    # img 디렉토리가 없으면 생성하기
    imgdir_name = 'img'
    if not os.path.isdir(imgdir_name):
        os.mkdir(imgdir_name)
    
    
    for img_url in img_url_list:
        res = requests.get(img_url, headers=req_header)
    
        if res.ok:
            img_data = res.content
            file_name = os.path.basename(img_url)
            # dir + file 경로 합치기 : os.path.join(dirname, filename)
            file_path = os.path.join(imgdir_name, file_name)

            with open(file_path, 'wb') as file:
                file.write(img_data)
        else:
            print(f'Error code : {res.status_code}')

else:
    print(f'Error Code : {res.status_code}')
# Out:
# 19

# %% [markdown]
# ### 3. 파일 업로드 하기
# * http://httpbin.org/post 업로드 요청을 할 수 있는 url

# %%
import requests

upload_files = {
    
}
#print(upload_files)

url = 'http://httpbin.org/post'
# file 업로드 하려면 requests의 post 함수에 files 속성을 사용합니다.
# Out:
# 200

# %% [markdown]
# ### 4. 캡챠(이미지) API 호출하기
# * urllib 사용
# * 1. 캡차 키 발급 요청
#   2. 캡차 이미지 요청
#   3. 사용자 입력값 검증 요청

# %%
# 캡차 키 발급 요청

# %%
# 캡차 이미지 요청

# %%
#  사용자 입력값 검증 요청

# %% [markdown]
# * requests를 사용하는 코드로 변경하기
# * [requests docs](https://requests.readthedocs.io/en/latest/user/quickstart/)

# %%
# 사용자 입력값 검증 요청
# Out:
# Error Code: 403

# %% [markdown]
# ### 5. 블로그 검색하기

# %%
import requests
import pprint

headers = {
    'X-Naver-Client-Id': '',
    'X-Naver-Client-Secret': '',
}

payload = {
    'query': '파이썬',
    'display': 100,
    'sort': 'sim'
}

url = 'https://openapi.naver.com/v1/search/blog.json'


# requests get(url, params, headers) 요청 

# json() 함수로 응답 결과 가져오오기
# 'title' , 'bloggername' , 'description' , 'bloggerlink' , 'link'

# 'data/nhnblog.txt' 파일 생성하기
